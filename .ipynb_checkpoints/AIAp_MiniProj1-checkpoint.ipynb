# %% [markdown]
# # Tasks
#
# [https://moodle.ost.ch/pluginfile.php/426498/mod_resource/content/1/AiAp23_MiniProj1.pdf](https://moodle.ost.ch/pluginfile.php/426498/mod_resource/content/1/AiAp23_MiniProj1.pdf)
#
# ---

# %% [markdown]
# # Miniproject 1
# # B.I. Bartificial Intelligence - Image Classifier for *The Simpsons*
# ![](https://static.wikia.nocookie.net/simpsons/images/8/8c/Treehouse_of_Horror_XVI_%28Promo_Picture%29_2.jpg/revision/latest?cb=20120625110202) |  ![](https://static.wikia.nocookie.net/simpsons/images/a/a9/B.I._Bartificial_Intelligence.jpg/revision/latest?cb=20121103214906)
# :---:|:---:
#
# > Authors 🗒
# > * Kyra Maag (kyra.maag@ost.ch)
# > * Nico Fehr (nico.fehr@ost.ch)
#
# Kyra: Einleitung
#
# For the first Miniproject we decided to train an image classifier for images of characters from the famous series "The Simpsons". The classifier can detect and predict the character shown on a given image.

# %% [markdown]
# ## Dataset
#
# Nico
#
# ### Source
# The dataset used in this miniproject was available on kaggle.com. The dataset contains 20 folders (one per each character in the series) with around 400-2000 images in each one.
#
# ### Pre-processing
# We reduced the dataset significantly to only work with 8 classes which will make the training faster.
#
# - test daten vorbereitet (ordnerstruktur)
# - train daten reduziert auf 8 klassen

# %% [markdown]
# ### Key characteristics
# - ordneranzahl und anzahl bilder beschreiben

# %% [markdown]
# ## Architecture 1 (simple, underfitted)
#
# ### Tasks
# * [ ] Define and train deep convolutional network (multi-class) with keras
# * [x] Not more than 3 layers, no more than 5'000 trainable parameters
# * [x] Network should underfit
# * [ ] Plot loss and accuracy evolvement
# * [ ] sufficient nr of epochs
# * [ ] training loss should converge
# * [ ] Plot confusion matrix
# * [ ] Discussion
#
# What is cross validation in the sense of keras? Is it the split of training data in a training part and validation part.

# %%
import tensorflow as tf

import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix

print(tf.__version__)
print(np.__version__)
# Out:
# 2.11.0
# 1.20.3

# %%
classification_labels = ["Bart Simpson",
          "Charles Montgomery Burns",
          "Homer Simpson",
          "Krusty The Clown",
          "Lisa Simpson",
          "Marge Simpson",
          "Moe Szyslak",
          "Ned Flanders",]

# %%
train_directory = 'simpsons-dataset/train'
test_directory = 'simpsons-dataset/test'

# %%
image_size = (50, 50)

train_data, validation_data = tf.keras.utils.image_dataset_from_directory(
    train_directory,
    validation_split=0.2,
    subset='both',
    seed=123,
    image_size=image_size,
    color_mode='rgb',
    labels='inferred',
    label_mode='int',
)

test_data = tf.keras.utils.image_dataset_from_directory(
    test_directory,
    image_size=image_size,
    color_mode='rgb',
    labels='inferred',
    label_mode='int'
)
# Out:
# Found 11538 files belonging to 8 classes.
# Using 9231 files for training.
# Using 2307 files for validation.
# Found 397 files belonging to 8 classes.

# %% [markdown]
# ### Exploring the data

# %%
plt.figure(figsize=(10,10))

for images, labels in train_data.take(1):
  for i in range(9):
      ax = plt.subplot(3, 3, i + 1)
      plt.imshow(images[i].numpy().astype("uint8"))
      plt.title(classification_labels[int(labels[i])])
      plt.axis("off")

# %% [markdown]
# Performance

# %%
train_data = train_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
validation_data = validation_data.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
input_shape = image_size + (3, )
print(input_shape)
num_classes = len(classification_labels)
# Out:
# (50, 50, 3)

# %%
model = keras.Sequential([
    layers.Input(shape=input_shape),
    layers.Rescaling(1./255),
    layers.Conv2D(2, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(5, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(num_classes),
])

model.summary()

keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_5 (Rescaling)     (None, 50, 50, 3)         0
#
#  conv2d_10 (Conv2D)          (None, 48, 48, 2)         56
#
#  max_pooling2d_10 (MaxPoolin  (None, 24, 24, 2)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 22, 22, 5)         95
#
#  max_pooling2d_11 (MaxPoolin  (None, 11, 11, 5)        0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 605)               0
#
#  dense_5 (Dense)             (None, 8)                 4848
#
# =================================================================
# Total params: 4,999
# Trainable params: 4,999
# Non-trainable params: 0
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
#callbacks = [
#    keras.callbacks.ModelCheckpoint("save_at_{epoch}.keras"),
#]

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

epochs = 25
history = model.fit(
    train_data,
    validation_data=validation_data,
    epochs=epochs,
    #callbacks=callbacks
)
# Out:
# Epoch 1/25
# 289/289 [==============================] - 6s 11ms/step - loss: 1.9385 - accuracy: 0.2580 - val_loss: 1.7252 - val_accuracy: 0.3537
# Epoch 2/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.6215 - accuracy: 0.4087 - val_loss: 1.5602 - val_accuracy: 0.4629
# Epoch 3/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.5298 - accuracy: 0.4551 - val_loss: 1.5284 - val_accuracy: 0.4647
# Epoch 4/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.4623 - accuracy: 0.4900 - val_loss: 1.4693 - val_accuracy: 0.4950
# Epoch 5/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.3967 - accuracy: 0.5186 - val_loss: 1.4220 - val_accuracy: 0.5028
# Epoch 6/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.3423 - accuracy: 0.5427 - val_loss: 1.3944 - val_accuracy: 0.5275
# Epoch 7/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.3043 - accuracy: 0.5606 - val_loss: 1.3491 - val_accuracy: 0.5431
# Epoch 8/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.2747 - accuracy: 0.5752 - val_loss: 1.3518 - val_accuracy: 0.5392
# Epoch 9/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.2521 - accuracy: 0.5798 - val_loss: 1.3338 - val_accuracy: 0.5431
# Epoch 10/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.2334 - accuracy: 0.5887 - val_loss: 1.3267 - val_accuracy: 0.5544
# Epoch 11/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.2150 - accuracy: 0.5896 - val_loss: 1.3169 - val_accuracy: 0.5596
# Epoch 12/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.2015 - accuracy: 0.6018 - val_loss: 1.3125 - val_accuracy: 0.5592
# Epoch 13/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.1872 - accuracy: 0.5976 - val_loss: 1.3288 - val_accuracy: 0.5574
# Epoch 14/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.1754 - accuracy: 0.6038 - val_loss: 1.3155 - val_accuracy: 0.5561
# Epoch 15/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.1620 - accuracy: 0.6074 - val_loss: 1.3433 - val_accuracy: 0.5457
# Epoch 16/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.1548 - accuracy: 0.6154 - val_loss: 1.3213 - val_accuracy: 0.5613
# Epoch 17/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.1448 - accuracy: 0.6168 - val_loss: 1.3131 - val_accuracy: 0.5691
# Epoch 18/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.1406 - accuracy: 0.6138 - val_loss: 1.2913 - val_accuracy: 0.5717
# Epoch 19/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.1348 - accuracy: 0.6184 - val_loss: 1.2932 - val_accuracy: 0.5787
# Epoch 20/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.1209 - accuracy: 0.6234 - val_loss: 1.2891 - val_accuracy: 0.5752
# Epoch 21/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.1172 - accuracy: 0.6226 - val_loss: 1.3104 - val_accuracy: 0.5687
# Epoch 22/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.1102 - accuracy: 0.6257 - val_loss: 1.2884 - val_accuracy: 0.5808
# Epoch 23/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.1054 - accuracy: 0.6299 - val_loss: 1.2880 - val_accuracy: 0.5752
# Epoch 24/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.1001 - accuracy: 0.6310 - val_loss: 1.3360 - val_accuracy: 0.5553
# Epoch 25/25
# 289/289 [==============================] - 3s 10ms/step - loss: 1.0971 - accuracy: 0.6269 - val_loss: 1.3119 - val_accuracy: 0.5665

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.2, 2])
plt.legend(loc='lower right')

# %%
test_loss, test_accuracy = model.evaluate(test_data, verbose=2)
# Out:
# 13/13 - 0s - loss: 1.2175 - accuracy: 0.5819 - 129ms/epoch - 10ms/step

# %%
probability_model = tf.keras.Sequential([model, layers.Softmax()])
prediction_labels = probability_model.predict(test_data, verbose=2)
# Out:
# 13/13 - 0s - 172ms/epoch - 13ms/step

# %%
prediction_labels = np.array([np.argmax(x) for x in prediction_labels])

# %%
true_labels = np.concatenate([y for x, y in test_data], axis=0)

# %%
print(true_labels)
# Out:
# [4 7 3 0 5 0 0 4 4 5 1 2 1 0 4 6 2 4 1 4 5 2 0 5 3 5 7 5 6 3 3 5 1 5 5 2 3
#  0 0 1 3 2 3 0 5 6 3 1 5 3 0 3 2 5 6 1 6 5 4 4 7 4 7 3 4 1 6 7 2 3 2 4 1 2
#  5 2 4 0 2 4 1 1 0 1 0 4 5 0 3 4 3 5 5 1 0 7 0 4 6 1 2 7 3 7 4 2 4 6 0 2 3
#  1 4 6 1 1 2 4 1 1 3 2 6 7 1 6 4 0 4 7 7 4 1 4 7 3 0 6 6 6 2 4 0 7 6 0 2 1
#  5 2 7 5 7 7 6 6 1 7 5 4 2 2 3 0 6 5 1 2 6 3 3 5 5 0 7 7 3 3 4 4 0 1 3 0 0
#  6 6 5 4 3 5 6 6 4 3 1 0 7 0 4 6 5 2 5 3 1 6 3 3 7 2 4 7 4 6 3 4 5 2 2 0 6
#  3 6 2 4 2 2 5 1 7 4 4 1 4 1 7 7 1 1 0 2 3 7 5 5 5 0 1 3 7 0 7 1 4 0 4 6 7
#  6 0 7 2 7 5 2 7 1 5 7 4 6 6 7 0 2 3 3 6 6 7 1 6 3 6 0 0 7 3 7 5 3 0 6 5 6
#  2 3 3 2 5 1 0 5 6 1 3 7 1 1 0 5 3 0 2 6 3 3 5 0 1 2 7 2 1 4 4 0 1 7 7 0 3
#  0 7 6 2 4 5 0 7 0 3 2 1 5 5 1 2 3 1 4 6 2 5 6 4 4 6 2 2 5 4 3 2 6 6 6 4 7
#  1 6 7 2 3 7 6 0 5 2 3 2 1 2 7 0 5 5 7 5 5 0 2 0 6 4 7]

# %%
print(prediction_labels)
# Out:
# [6 6 2 4 0 5 0 2 6 5 6 3 5 5 3 2 6 0 4 1 2 0 1 3 7 7 1 4 3 0 2 2 1 3 4 7 1
#  5 7 7 0 3 2 4 0 3 1 0 3 4 2 4 2 3 6 7 2 4 1 3 7 7 3 7 0 0 0 7 0 3 7 3 0 1
#  0 7 7 2 2 2 7 5 3 2 5 7 0 2 2 2 2 7 1 0 0 3 3 6 0 0 7 7 3 2 2 3 2 7 1 7 4
#  6 2 0 2 1 4 4 1 0 5 2 0 2 3 7 2 4 3 2 0 4 0 6 2 2 2 2 2 5 2 5 2 0 3 6 1 3
#  5 0 1 0 0 1 2 0 0 7 1 2 2 2 3 3 4 5 7 6 6 3 7 6 6 2 0 7 3 2 6 4 1 5 4 4 2
#  2 7 0 5 7 1 4 3 7 7 5 7 5 7 3 3 4 0 5 5 0 6 1 6 0 3 3 1 4 3 5 1 4 4 5 4 1
#  0 5 3 6 1 4 3 0 2 7 6 2 4 5 7 0 4 3 7 4 2 6 7 2 1 2 7 4 7 1 0 4 3 1 1 6 7
#  2 2 3 6 0 0 3 2 2 0 7 1 4 5 6 4 2 0 6 5 0 4 3 0 7 2 1 1 2 3 2 7 3 1 6 2 0
#  0 1 6 0 4 0 7 0 6 2 4 1 1 6 6 6 5 0 2 0 0 5 4 0 1 2 1 7 4 3 4 0 2 0 6 5 6
#  4 2 0 3 4 3 0 7 0 0 2 2 2 0 0 6 5 3 3 0 2 6 2 3 2 6 0 7 2 3 1 5 1 4 2 5 2
#  4 3 2 1 5 5 6 5 3 7 2 3 0 6 0 1 3 5 6 5 6 2 0 3 5 6 2]

# %%
cm = confusion_matrix(true_labels, prediction_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classification_labels)
disp.plot(cmap=plt.cm.GnBu, xticks_rotation='vertical')
plt.rcParams["figure.figsize"] = (8, 8)
plt.title("Confusion Matrix of the first Model Architecture")
plt.show()

# %% [markdown]
# ## Discussion

# %% [markdown]
# ## Architecture 2 (overfitted)
# ### Tasks
#
# * [ ] Change number of layers, filters (=kernels), number of neurons
# * [ ] Make network too complex (overfitting)
# * [ ] Plot learning curves
# * [ ] Plot confusion matrix
# * [ ] Discussion

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %% [markdown]
# ## Architecture 2 (optimized)
# ### Tasks
# * [ ] Add dropout layer
# * [ ] add L2 regularization to at least one layer [Weight Regularization](https://machinelearningmastery.com/how-to-reduce-overfitting-in-deep-learning-with-weight-regularization)
# * [ ] K-fold cross-validation (k >= 5) to find optimal L2 regularization parameter value

# %% [markdown]
# ## Discussion
#
# * [ ] Observations
# * [ ] Draw conclusions

# %% [markdown]
# ### Comparison
#
# Compare
# * nr of parameters
# * nr of epochs
# * test performance
